# %%
from sympy import init_printing
init_printing(use_latex = True)
from sympy import *
import numpy as np
import matplotlib.pyplot as plt

from sympy.abc import x,y,z,a,b,c,d

# %%
#0 leq y leq 2-x^2
p1 = plot_implicit(And(0<=y,y<=2-x**2))
