# %%
from sympy import init_printing
init_printing(use_latex = True)
from sympy import *

# library
import numpy as np
import matplotlib.pyplot as plt


# Create data
x=range(1,6)
y=[1,4,6,8,4]

# Area plot
plt.fill_between(x, y)
plot.show()

# %%
# Import numpy library
import numpy as np

# Parametres
Ro  = 
r   = 1
tht = np.linspace(0, 2* np.pi, 50)
phi = np.linspace(0, 2* np.pi, 50)

# Meshgrid to create mesh
tht, phi = np.meshgrid(tht, phi)

# Parametric equations in cartesian co-ordinates
x = (Ro + r* np.cos(tht))* np.cos(phi)
y = (Ro + r* np.cos(tht))* np.sin(phi)


# Import plotting libraries
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d as Axes3D

# Adjustment for figure
fig = plt.figure('Parametric Surfaces')
ax  = fig.add_subplot(111, projection='3d')

# Plot the data
h = ax.plot_surface(x, y, z, cmap = 'jet', edgecolor = 'k')

# Colorbar for easy visualization
fig.colorbar(h)

# Add labels
ax.set_xlabel('X', fontweight = 'bold', fontsize = 14)
ax.set_ylabel('Y', fontweight = 'bold', fontsize = 14)
ax.set_zlabel('Z', fontweight = 'bold', fontsize = 14)

# Add title
ax.set_title('Parametric Surface', fontweight = 'bold', fontsize = 16)


# Finally show the figure
plt.show()

# %%
from sympy import init_printing
init_printing(use_latex = True)
from sympy import *

x,y,z,t= symbols("x y z t")
#insert f(x,y,...)


origin = 2*x*y+y**2
test = diff(origin,x)
plot(test)

plot(origin, (x, 1, 3),(y,1,3))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-d3a4f74b60e5> in <module>
#      11 plot(test)
#      12
# ---> 13 plot(origin, (x, 1, 3),(y,1,3))
#      14
#      15
#
# ~\anaconda3\lib\site-packages\sympy\plotting\plot.py in plot(*args, **kwargs)
#    1631             free |= a.free_symbols
#    1632             if len(free) > 1:
# -> 1633                 raise ValueError(
#    1634                     'The same variable should be used in all '
#    1635                     'univariate expressions being plotted.')
#
# ValueError: The same variable should be used in all univariate expressions being plotted.
