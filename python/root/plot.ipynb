# %%
import matplotlib.pyplot as plt

time = [0, 1, 2, 3]
position = [0, 100, 200, 300]

plt.plot(time, position)
plt.xlabel('Time (s)')
plt.ylabel('Position (m)')

plt.show5

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(100000, 10000, 1000)
y = np.sin(x)
plt.plot(x, y)
